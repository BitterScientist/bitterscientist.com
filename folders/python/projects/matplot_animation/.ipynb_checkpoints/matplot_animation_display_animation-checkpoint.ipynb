# %%
#Display the animation...
import io
import base64
from IPython.display import HTML

filename = 'parabola_der_animation.gif'

video = io.open(filename, 'r+b').read()
encoded = base64.b64encode(video)
HTML(data='''<img src="data:image/gif;base64,{0}" type="gif" />'''.format(encoded.decode('ascii')))
# Out:
# <img src="data:image/gif;base64,..." type="gif" />

# %% [markdown]
# # Dependencies
#
# <strong><code>import io</code></strong>
#  - <strong>What it does:</strong> Core tools for working with streams.
#  - Documentation: https://docs.python.org/3/library/io.html
#
# <strong><code>import base64</code></strong>
#  - <strong>What it does:</strong> This module provides functions for encoding binary data to printable ASCII characters and decoding such encodings back to binary data.
#  - Documentation: https://docs.python.org/3/library/base64.html
#
# <strong><code>from IPython.display import HTML</code></strong>
#  - <strong>What it does:</strong> Public API for display tools in IPython. Renders HTML jupyter notebook.
#  - Documentation: https://ipython.readthedocs.io/en/stable/api/generated/IPython.display.html

# %% [markdown]
# ### Import File
#
# <strong><code>filename = 'parabola_der_animation.gif'</code></strong>
#  - <strong>What it does:</strong> saves file name to variable
#
# <strong><code>video = io.open(filename, 'r+b').read()</code></strong>
#  - <strong>What it does:</strong> This function raises an auditing event open with arguments path, mode and flags. The mode and flags arguments may have been modified or inferred from the original call. Saved to <code>video</code> variable.
#   - <strong>Parameters:</strong>:
#    - <code>filename</code>: the file that will be opened
#    - <code>'r+b'</code>: method the file will be read, in binary format
#
# <strong><code>encoded = base64.b64encode(video)</code></strong>
#  - <strong>What it does:</strong> Encode the bytes-like object s using Base64 and return the encoded bytes.
#
# ### Display File
#
# <strong><code>HTML(data=''' '''.format(encoded.decode('ascii')))</code></strong>
#  - <strong>What it does:</strong> displays the gif file
