# %%
import json, requests

response = requests.get("https://api.sportsdata.io/v3/nfl/scores/json/Players/TB?key=7b1ed44954754322941881c98adb4edd").json()
# Out:
# [{'PlayerID': 15231, 'Team': 'TB', 'Number': None, 'FirstName': 'Earl', 'LastName': 'Watford', 'Position': 'G', 'Status': 'Practice Squad', 'Height': '6\'3"', 'Weight': 300, 'BirthDate': '1990-06-24T00:00:00', 'College': 'James Madison', 'Experience': 13, 'FantasyPosition': 'OL', 'Active': True, 'PositionCategory': 'OFF', 'Name': 'Earl Watford', 'Age': 30, 'ExperienceString': '7th Season', 'BirthDateString': 'June 24, 1990', 'PhotoUrl': 'https://s3-us-west-2.amazonaws.com/static.fantasydata.com/headshots/nfl/low-res/15231.png', 'ByeWeek': 13, 'UpcomingGameOpponent': 'KC', 'UpcomingGameWeek': 4, 'ShortName': 'E.Watford', 'AverageDraftPosition': None, 'DepthPositionCategory': 'Scrambled', 'DepthPosition': 'Scrambled', 'DepthOrder': None, 'DepthDisplayOrder': None, 'CurrentTeam': 'TB', 'CollegeDraftTeam': 'ARI', 'CollegeDraftYear': 2013, 'CollegeDraftRound': 8, 'CollegeDraftPick': 160, 'IsUndraftedFreeAgent': False, 'HeightFeet': 6, 'HeightInches': 3, 'UpcomingOpponentRank': 22, 'Upcomi
# ...

# %%
import pandas as pd
url = "https://api.sportsdata.io/v3/nfl/scores/json/Players/TB?key=7b1ed44954754322941881c98adb4edd"
df = pd.read_json(url)

# %%
df.to_csv("tampabay_team_stats.csv", index=False)

# %%
tampabay_weights.to_csv('tambapay_weights.csv', index=False)

# %%
url = "https://api.sportsdata.io/v3/nfl/scores/json/Players/KC?key=7b1ed44954754322941881c98adb4edd"
kc_df = pd.read_json(url)
kc_df.to_csv("kansascity_team_stats.csv", index=False)

# %%
kc_df.head()
# Out:
#    PlayerID Team  Number FirstName      LastName Position          Status  \
# 0     19559   KC     NaN      Sean        Culkin       TE  Practice Squad
# 1     19917   KC     NaN   Antonio      Callaway       WR  Practice Squad
# 2     21612   KC     NaN    Jordan        Ta'amu       QB  Practice Squad
# 3     21816   KC     NaN   Anthony        Gordon       QB  Practice Squad
# 4     22020   KC     NaN    Prince  Tega Wanogho       OT  Practice Squad
#
#   Height  Weight            BirthDate  ... GlobalTeamID  FantasyDraftPlayerID  \
# 0   6'5"     255  1993-06-11T00:00:00  ...           16              689866.0
# 1  5'11"     200  1997-01-09T00:00:00  ...           16              879022.0
# 2   6'3"     214  1997-12-10T00:00:00  ...           16              974470.0
# 3   6'2"     201  1996-08-28T00:00:00  ...           16                   NaN
# 4   6'5"     308  1997-11-22T00:00:00  ...           16                   NaN
#
#    FantasyDraftName  UsaTodayPlayerID  \
# ...

# %%
kansas_weights = kc_df.Weight
kansas_weights.to_csv('kansascity_weights.csv', index=False)
