# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %% [markdown]
# <div class="alert alert-block alert-info" style="font-size:20px; border:1px solid black; padding:10px">
# <center><h1>Post Goals:</h1></center>
#     <ol>
#         <li>Provide a Concise Introduction to Support Vector Machine Regression.</li><br>
#         <li>Demonstrate how to perform Support Vector Machine Regression using Python's Sklean library.</li><br>
#     </ol>
# </div>

# %% [markdown]
# <hr style="border-top: 5px solid black;">

# %%
# to load images for this tutorial
from IPython.display import Image
import os
path = os.getcwd()

# Math libraries
import numpy as np

# Data visualization module
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# Key ML modules
from sklearn.svm import LinearSVR
from sklearn.svm import SVR

# %% [markdown]
# <div style="font-size:16px; border:1px solid black; padding:10px">
# <center><h1><br><font color="blue">Post Overview.</font></h1></center>
#     <ol>
#         <li><a href="#objective1">Introduction to Suppor Vector Machine (SVM).</a></li><br>
#         <li><a href="#objective2">Introduction to Suppor Vector Machine (SVM) Regression.</a></li><br>
#         <li><a href="#objective3">Mathematic Intuition of Suppor Vector Machine (SVM) Regression.</a></li><br>
#         <li><a href="#objective4">Demonstrate how to carry out SVM Regression using <code>LinearSVR()</code> for both linear and nonlinear data.</a></li><br>
#     </ol>
# </div>

# %% [markdown]
# <hr style="border-top: 5px solid black;">

# %% [markdown]
# <div id="objective1" style="font-size:16px; border:1px solid black; padding:10px">
# <center><h1><br><font color="blue">Introduction to Suppor Vector Machine (SVM).</font></h1></center>
#     <hr>
#     <ul><h4></h4>
#         <li>Support Vector Machine algorithm is a powerful supervised Machine Learning Models capable of performing
#             <ul>
#         <li>Linear classification</li>
#         <li>Nonlinear classification</li>
#         <li><font color="red">Regression</font></li>
#         <li>Outlier detection</li>
#             </ul>
#         </li><br>
#         <li>SVM is one of the most popular machine learning models and is well suited for classification of complex datasets that are small and medium sized.</li><br>
#         <li>Like logistic regression, support vector machines were designed for binary classification and do not natively support classification tasks with more than two classes.</li><br>
#         <li>In this algorithm, data is plotted in n-dimensional space (where n is number of features you have). Then, we perform classification by finding a decision boundary (aka hyperplane in 3d+) that best differentiates the two classes.</li><br>
#         <li><mark style="background-color: yellow;">The objective of the support vector machine algorithm is to find a hyperplane in an N-dimensional space(N — the number of features) that distinctly classifies the data points.</mark></li><br>
#         <li>Decision boundaries are used in SVM to help sort data into categories for classification.</li><br>
#         <li>Although linear SVM classification is generally efficient and works in many cases, most datasets are not linearly separable.</li><br>
#         <li>Nonlinear SVM classification are methods used to work with nonlinear data and includes:
#             <ul>
#                 <li>Polynomial Features</li>
#                 <li>Polynomial Kernel</li>
#                 <li>Similarity Features</li>
#                 <li>Gaussian RBF Kernel</li>
#             </ul>
#         </li><br>
#         <li>SVM is popular because of the Kernel functions, which helps solve nonlinearity, especially for complex datasets.</li><br>
#         <li>The method used to handle nonlinearity depends on the size of the dataset, it's complexity, and the computational resources available.</li><br>
#         <li>Although SVM is commonly used for classification, it can also be used for regression.</li><br>
#         <li>Regression is a statistical modeling technique that is used to estimate the relationship between two continuous variables.</li><br>
#         <li>Regression aims to predict the value of a dependent variable based on the value of an independent variable.</li><br>
#         <li><font color="red">This post will focus on SVM Regression.</font></li><br>
#     </ul>
# </div>

# %% [markdown]
# <hr style="border-top: 5px solid black;">

# %% [markdown]
# <div id="objective2" style="font-size:16px; border:1px solid black; padding:10px">
# <center><h1><br><font color="blue">Introduction to Suppor Vector Machine (SVM) Regression.</font></h1></center>
#     <hr>
#     <ul><h4>What is SVM Regression and How is it Different from Linear Regression.</h4>
#         <li>Support vectors machine algorithms are often used for classification problems, but can also be used in regression.</li><br>
#         <li>SVM methods used to predict the value of a dependent variable based on the value of an independent variable are referred to as SVM Regression.</li><br>
#         <li>SVR provides a flexible way to define how much error is acceptable in the regression model and will find an appropriate line (or hyperplane in higher dimensions) to fit the data.</li><br>
#         <li>Unlike Linear Regression, SVM Regression minimizes the L2-norm of the coefficient vector and not the squared error.</li><br>
#         <li>The weights of each feature in SVM regression reflect their true contribution, unlike Linear regression, gives the biggest weight to features that are best correlated to the dependent variable.</li><br>
#     </ul>
# </div>

# %% [markdown]
# <hr style="border-top: 5px solid black;">

# %% [markdown]
# <div id="objective3" style="font-size:16px; border:1px solid black; padding:10px"><center><h1><br><font color="blue">Mathematic Intuition of Suppor Vector Machine (SVM) Regression.</font></h1></center>
#     <hr>
#     <ul><strong>&epsilon; the margin of error in SVM Regression</strong>:
#         <li>The objective function of SVM Regression is to minimize the L2-norm of the coefficient vectors:<br><br>
#             <strong>MIN &#189;||w||<sup>2</sup></strong>.</li><br>
#         <li>The error term is handled in the models constraints, as expressed:
#             <br><br>
#             <strong>|y<sub>i</sub> - w<sub>i</sub>x<sub>i</sub>| &#8804; &epsilon; </strong><br><br>
#             where <strong>y<sub>i</sub></strong> is the target<br>
#             <strong>w<sub>i</sub></strong> is the coefficient<br>
#             <strong>x<sub>i</sub></strong> is the predictor (feature)
#         </li><br>
#         <li>This is illustrated in <a href="#example1">example 1</a>.</li><br>
#         <li>The maximum error <strong>&epsilon; (epsilon)</strong> is the constraint, which is the absolute error less than or equal to the specified margin, and is illustrated in <a href="#example1">example 1</a>.</li><br>
#         <li>The <strong>&epsilon; (epsilon)</strong> can be tuned to gain a desired accuracy in the model.</li><br>
#         <li>The red line in <a href="#example1">example 1</a> is the best fit line and the black lines represent the margin of error <strong>&epsilon; (epsilon)</strong>.</li><br>
#     </ul>
#     <hr>
#     <ul><strong>&zeta;(zeta)</strong>:
#         <li>The algorithm does not always work for all data points, as some points may fall outside the margins, as illustrated in <a href="#example1">example 1</a> where you have blue data points above or below the black lines that represent the margin of error <strong>&epsilon; (epsilon)</strong>.</li><br>
#         <li>To account for the errors that are larger than <strong>&epsilon; (epsilon)</strong>, we use a slack variable called <strong>&zeta;(zeta)</strong>.</li><br>
#         <li><strong>&zeta;(zeta)</strong> is the deviation from the margin, and we we would like to minimize these as much as possible, so we can add these to the objective function.</li><br>
#         <li>Minimize function that takes <strong>&zeta;(zeta)</strong> into account is defined as:
#             <br><br>
#              <strong><em>MIN &#189;||w||<sup>2</sup> + C * &Sigma;<sup>n</sup><sub>i=1</sub>|&zeta;<sub>i</sub>| </em></strong>.
#         </li><br>
#         <li>The contraints is also updated to account for &zeta;:
#             <br><br>
#             <strong>|y<sub>i</sub> - w<sub>i</sub>x<sub>i</sub>| &#8804; &epsilon; + &zeta;<sub>i</sub>| </strong>
#         </li><br>
#     </ul>
#     <hr>
#     <ul><strong><code>C</code> hyperparameter</strong>:
#         <li>We now have an additional hyperparameter, <strong><code>C</code></strong>, that is used to adjust the tolerance for points outside of the margins &epsilon;</li><br>
#         <li>As <strong><code>C</code> &uarr;:</strong> tolerance for points outside of &epsilon; also &uarr;</li><br>
#         <li>As <strong><code>C</code> &darr;:</strong> tolerance for points outside of &epsilon; also &darr;:</li><br>
#         <li>Finding the best value for the <strong><code>C</code> hyperparameter</strong> is important to obtain the best model.</li><br>
#         <li>One method commonly used to identify the optimal <strong><code>C</code> hyperparameter</strong> is through a grid search over <code>C</code> to obtain a scoring metric <em>% within Episolon</em> score.</li><br>           <li><em>% within Episolon</em> measures how many of the total points within the test set falls within our margen of error.</li><br>
#         <li>A second method commonly used to identify the optimal <strong><code>C</code> hyperparameter</strong> is through monitoring the <em>Mean Absolute Error (MAE)</em> score.</li><br>
#         <li>The <em>Mean Absolute Error (MAE)</em> score generally decreases as <code>C</code> increases.</li><br>
#         <li>You can then find the value of <code>C</code> that will maximizes the prediction within a target margin of error with these methods.</li><br>
#     </ul>
# </div>

# %% [markdown]
# <div id="example1">
# </div>

# %%
img = os.path.join(path, 'static/images/svr/example1.png')
Image(filename=img)

# %% [markdown]
# <hr style="border-top: 5px solid black;">

# %% [markdown]
# <div id="objective4" style="font-size:16px; border:1px solid black; padding:10px">
# <center><h1><br><font color="blue">Demonstrate how to carry out SVM Regression using <code>LinearSVR()</code> for both linear and nonlinear data.</font></h1></center>
#     <ol><strong>General Steps</strong>:
#         <li>Load Data</li>
#         <li>Prepare target and feature variables in the right data structure.</li>
#         <li>Train <code>LinearSVR()</code> model.</li>
#         <li>Fit the model according to the given data.</li>
#         <li>Graphically Evaluate Model.</li>
#     </ol>
#     <li>Note: the purpose of this post is to demonstrate how to use Sklearn to conduct a SVM Regression, these examples will not split data into test and train sets.</li>
# <hr>
#         <ul>
#         <li>Dummy data will be used in this example (50 data points).</li>
#         <li>The data structure for <code>LinearSVR()</code>:
#             <ul>
#                 <li>The feature variable as a 2-D array.</li>
#                 <li>The target variable as a 1-D array.</li>
#             </ul>
#         </li>
#         <li>Custom functions are used to get the suppor vectors and plot regression.</li>
#         <li>
#             <ol><mark><strong>Learning Objective:</strong></mark>:
#                 <li>Demonstrate how to carry out SVM Regression on linear data.</li>
#                 <li>Demonstrate how the hyperparameter <strong>&epsilon; (epsilon)</strong> affects the model.</li>
#             </ol>
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <h2>Load Data</h2>

# %%
np.random.seed(42)
m = 50
X = 2 * np.random.rand(m, 1)
y = (4 + 3 * X + np.random.randn(m, 1)).ravel()

# %% [markdown]
# <div class="alert alert-block alert-warning" style="font-size:11px; border:0.5px solid black; padding:5px">
# <center><h1>Code Explained:</h1></center>
#     <ol><strong>Code Line</strong>
#         <li><a href="https://numpy.org/doc/stable/reference/random/generated/numpy.random.seed.html"><code>np.random.seed(42)</code></a>: every time you call the numpy's other random function, the result will be the same:</li>
#         <li><code>m = 50</code>: number of data instances</li>
#         <li><code>X = 2 * <a href="https://numpy.org/doc/stable/reference/random/generated/numpy.random.rand.html">np.random.rand(m, 1)</a></code>: Create an array of the given shape and populate it with random samples from a uniform distribution over . In this example, an array of 50 instances, each instance is a value between [0,1], and then each value is multiplied by 2.</li>
#         <li><code>y = (4 + 3 * X + np.random.randn(m, 1)).ravel()</code>: Creates target value, an array of 50 instances, a value between [0,1], + a value in X multiplied by 4, plus a constant value 4.</li>
#     </ol>
# </div>

# %% [markdown]
# <h2>Train Model and Fit Data</h2>

# %%
svm_reg1 = LinearSVR(epsilon=1.5, random_state=42)
svm_reg2 = LinearSVR(epsilon=0.5, random_state=42)
svm_reg1.fit(X, y)
svm_reg2.fit(X, y)
# Out:
# LinearSVR(epsilon=0.5, random_state=42)

# %% [markdown]
# <div class="alert alert-block alert-warning" style="font-size:11px; border:0.5px solid black; padding:5px">
# <center><h1>Code Explained:</h1></center>
#     <ol><strong>Code Line</strong>
#         <li><a href="https://scikit-learn.org/stable/modules/generated/sklearn.svm.LinearSVR.html"><code>svm_reg1 = LinearSVR(epsilon=1.5, random_state=42)</code> Train a model with the following parameters</a>:
#             <ul>
#                 <li><strong>&epsilon; (float, default = 0.0)</strong> at 1.5</li>
#                 <li><strong>random_state (int, default = None)</strong> Controls the pseudo random number generation for shuffling the data, so get reproducible output accross multiple function calls.</li>
#             </ul>
#         </li>
#         <li><a href="https://scikit-learn.org/stable/modules/generated/sklearn.svm.LinearSVR.html"><code>svm_reg1 = LinearSVR(epsilon=1.5, random_state=42)</code> Train a model with the following parameters</a>:
#             <ul>
#                 <li><strong>&epsilon; (float, default = 0.0)</strong> at 0.5</li>
#                 <li><strong>random_state (int, default = None)</strong> Controls the pseudo random number generation for shuffling the data, so get reproducible output accross multiple function calls.</li>
#             </ul>
#         </li>
#         <li><code>svm_reg1.fit(X, y)</code>: Fit the model according to the given training data (code line 1).</li>
#         <li><code>svm_reg2.fit(X, y)</code>: Fit the model according to the given training data (code line 2).</li>
#     </ol>
# </div>

# %% [markdown]
# <h2>Obtain Array of Support Vectors for Plotting Purposes</h2>
#
#  - Custom function takes the Trained model, Target Array, and Features data.
#  - the

# %%
def find_support_vectors(svm_reg, X, y):
    y_pred = svm_reg.predict(X)
    off_margin = (np.abs(y - y_pred) >= svm_reg.epsilon)
    return np.argwhere(off_margin)

# %% [markdown]
# <div class="alert alert-block alert-warning" style="font-size:11px; border:0.5px solid black; padding:5px">
# <center><h1>Code Explained:</h1></center>
#     <li><strong>Function Output:</strong> determines the support vectors and returns an array of indices of support vector of shape (n_SV,).</li>
#     <li><strong>Purpose:</strong> will be used to identify and mark support vectors when plotted.</li>
#     <ol><strong>Code Line</strong>
#         <li><code>def find_support_vectors(svm_reg, X, y)</code>: Starts and names a function with three parameters</li>
#         <ul><strong>parameters</strong>
#             <li><code>svm_reg</code>: the trained model</li>
#             <li><code>X</code>: the feature variables array</li>
#             <li><code>y</code>: the target variable array</li>
#         </ul>
#         <li><code>y_pred = svm_reg.predict(X)</code>: perform regression on samples in X.</li>
#         <li><code>off_margin = (np.abs(y - y_pred) >= svm_reg.epsilon)</code>:
#             <ul><strong>Steps</strong>
#                 <li><code>np.abs(y - y_pred)</code>: The difference between the target value and the predicted y value</li>
#                 <li><code>svm_reg.epsilon</code>: is the &epsilon; value that was put in the paramater.</li>
#                 <li><code>(np.abs(y - y_pred) >= svm_reg.epsilon)</code>: If the difference between the actual target and the predicted is greater than the error epsilon, then save that as True, else False. This will save an array with boolean values.</li>
#             </ul>
#         </li>
#         <li><code>return np.argwhere(off_margin)</code>: Uses <a href="https://numpy.org/doc/stable/reference/generated/numpy.argwhere.html">numpy.argwhere</a>, which is method that returns an array (N, a.ndim) that contains indices where the difference of the target value and the predicted value is greater than the epsilon value.</li>
#     </ol>
# </div>

# %%
# Get support vector data points
svm_reg1.support_ = find_support_vectors(svm_reg1, X, y)
svm_reg2.support_ = find_support_vectors(svm_reg2, X, y)

# %% [markdown]
# <div class="alert alert-block alert-warning" style="font-size:11px; border:0.5px solid black; padding:5px">
# <center><h1>Code Explained:</h1></center>
#     <li><strong>Purpose:</strong> Evokes the <code>find_support_vectors</code> function, and save the array of indices.</li>
#     <ol><strong>Code Line</strong>
#         <li><code>svm_reg1.support_ = find_support_vectors(svm_reg1, X, y)</code>: indices of support vectors using the svm regression model trained wih &epsilon; = 1.5</li>
#         <li><code>svm_reg1.support_ = find_support_vectors(svm_reg1, X, y)</code>: indices of support vectors using the svm regression model trained wih &epsilon; = 0.5</li>
#     </ol>
# </div>

# %%
def plot_svm_regression(svm_reg, X, y, axes):
    x1s = np.linspace(axes[0], axes[1], 100).reshape(100, 1)
    y_pred = svm_reg.predict(x1s)
    plt.plot(x1s, y_pred, "k-", linewidth=2, label=r"$\hat{y}$")
    plt.plot(x1s, y_pred + svm_reg.epsilon, "k--")
    plt.plot(x1s, y_pred - svm_reg.epsilon, "k--")
    plt.scatter(X[svm_reg.support_], y[svm_reg.support_], s=180, facecolors='#FFAAAA')
    plt.plot(X, y, "bo")
    plt.xlabel(r"$x_1$", fontsize=18)
    plt.legend(loc="upper left", fontsize=18)
    plt.axis(axes)

# %% [markdown]
# <div class="alert alert-block alert-warning" style="font-size:11px; border:0.5px solid black; padding:5px">
# <center><h1>Code Explained:</h1></center>
#     <li><strong>Purpose:</strong> Will plot the support vector machine regression and marks the support vectors.</li>
#     <ol><strong>Code Line</strong>
#         <li><code>def plot_svm_regression(svm_reg, X, y, axes):</code>: Plots the SVM Regression and marks the support vectors.</li>
#         <ul><strong>parameters</strong>
#             <li><code>svm_reg</code>: the trained model</li>
#             <li><code>X</code>: the feature variables array</li>
#             <li><code>y</code>: the target variable array</li>
#             <li><code>axes</code>: the axis dimensions with four values [x min, x max, y min, y max]</li>
#         </ul>
#         <li><code>x1s = np.linspace(axes[0], axes[1], 100).reshape(100, 1)</code>: uses the <a href="https://numpy.org/doc/stable/reference/generated/numpy.linspace.html">numpy linespace</a> to return evenly spaced numbers over a specified interval.  gives a new shape to an array, and this is used to
#             <ul><strong>parameters: <code>numpy.linspace(start, stop, num=50, endpoint=True, retstep=False, dtype=None, axis=0)</code>:</strong>
#                 <li><code>axes[0]</code>: start, The starting value of the sequence.</li>
#                 <li><code>axes[1]</code>: stop, The end value of the sequence.</li>
#                 <li><code>100</code>: Number of samples to generate.</li>
#                 <li><code>.reshape(100, 1)</code>: This is chained after the linspace() method, and uses the <a href="https://numpy.org/doc/stable/reference/generated/numpy.reshape.html">Numpy Reshape</a> method that Gives a new shape to an array without changing its data. This method takes 3 parameters:
#                     <ul><strong>parameters</strong>
#                         <li><code>100</code>: the number of rows</li>
#                         <li><code>1</code>: the number of columns</li>
#                     </ul>
#                 </li>
#                 </ul>
#         </li>
#         <li><code>y_pred = svm_reg.predict(x1s)</code>: Perform regression on the linspace data and saves value to a new prediction array.</li>
#         <li><code>plt.plot(x1s, y_pred, "k-", linewidth=2, label=r"$\hat{y}$")</code>: plots a black line with the data from linspace as the x values, and the y_pred as the y values.</li>
#         <li><code>plt.plot(x1s, y_pred + svm_reg.epsilon, "k--")</code>: plots the upper margin boundary as a line</li>
#         <li><code>plt.plot(x1s, y_pred - svm_reg.epsilon, "k--")</code>: plots the lower margin boundary as a line</li>
#         <li><code>plt.scatter(X[svm_reg.support_], y[svm_reg.support_], s=180, facecolors='#FFAAAA')</code>: plots the support vectors as a scatter plot and adds a color</li>
#         <li><code> plt.plot(X, y, "bo")</code>: plots the original data as "bo" blue circles</li>
#         <li><code>plt.xlabel(r"$x_1$", fontsize=18)</code>: labels x axis</li>
#         <li><code>plt.legend(loc="upper left", fontsize=18)</code>: Adds the legend upper left corner with font size 18.</li>
#         <li><code>plt.axis(axes)</code>: add the specific x min, x max, y min, and y max boundaries.</li>
#     </ol>
# </div>

# %%
eps_x1 = 1
eps_y_pred = svm_reg1.predict([[eps_x1]])

fig, axes = plt.subplots(ncols=2, figsize=(9, 4), sharey=True)
plt.sca(axes[0])
plot_svm_regression(svm_reg1, X, y, [0, 2, 3, 11])
plt.title(r"$\epsilon = {}$".format(svm_reg1.epsilon), fontsize=18)
plt.ylabel(r"$y$", fontsize=18, rotation=0)

plt.annotate(
        '', xy=(eps_x1, eps_y_pred), xycoords='data',
        xytext=(eps_x1, eps_y_pred - svm_reg1.epsilon),
        textcoords='data', arrowprops={'arrowstyle': '<->', 'linewidth': 1.5}
    )
plt.text(0.91, 5.6, r"$\epsilon$", fontsize=20)
plt.sca(axes[1])
plot_svm_regression(svm_reg2, X, y, [0, 2, 3, 11])
plt.title(r"$\epsilon = {}$".format(svm_reg2.epsilon), fontsize=18)
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-warning" style="font-size:11px; border:0.5px solid black; padding:5px">
# <center><h1>Code Explained:</h1></center>
#     <li><strong>Purpose:</strong> Plots the support vector machine regression and marks the support vectors. Adds additional labels.</li>
#     <ol><strong>Code Line</strong>
#         <li><code>eps_x1 = 1</code>: save the x1 value = 1.0 in the plot</li>
#         <li><code>eps_y_pred = svm_reg1.predict([[eps_x1]])</code>: returns the predicted value at 1.0, this will be used for plotting the labels with epsilon on the left plot.</li>
#         <li><code>fig, axes = plt.subplots(ncols=2, figsize=(9, 4), sharey=True)</code>: uses <a href="https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.subplots.html">matplotlib.pyplot.subplot</a> to create a figure and a set of subplots.<br>
#             <code>matplotlib.pyplot.subplots(nrows=1, ncols=1, *, sharex=False, sharey=False, squeeze=True, subplot_kw=None, gridspec_kw=None, **fig_kw)[source]</code>
#         <ul><strong>parameters</strong>
#             <li><code>ncols=2</code>: 2 subplots in a column each</li>
#             <li><code>figsize=(9, 4)</code>: Width, height in inches of figure</li>
#             <li><code>sharex=False</code>: shared x value</li>
#             <li><code>sharey=False</code>: share y values</li>
#         </ul>
#         <li><code>plt.sca(axes[0])</code>: Set the current Axes to ax and the current Figure to the parent of ax.</li>
#         <li><code>plot_svm_regression(svm_reg1, X, y, [0, 2, 3, 11])</code>: evokes the plot_svm_regression</li>
#         <li><code>plt.title(r"$\epsilon = {}$".format(svm_reg1.epsilon), fontsize=18)</code>: Labels the subplot with the epsilon used in svm_reg1</li>
#         <li><code>plt.ylabel(r"$y$", fontsize=18, rotation=0)</code>: Labels the y axis.</li>
#         <li><code>plt.annotate('', xy=(eps_x1, eps_y_pred), xycoords='data',xytext=(eps_x1, eps_y_pred - svm_reg1.epsilon), textcoords='data', arrowprops={'arrowstyle': '&#60;-&#62;', 'linewidth': 1.5})</code>: Adds the epsilon label in the left plot.</li>
#         <li><code>plt.text(0.91, 5.6, r"$\epsilon$", fontsize=20)</code>: adds the &epsilon; on the label at the position 0.91 and 5.6.</li>
#         <li><code>plt.sca(axes[1])</code>: Changes to the second subplot.</li>
#         <li><code>plot_svm_regression(svm_reg2, X, y, [0, 2, 3, 11])</code>: created a new subplot with the second SVM Regression.</li>
#         <li><code>plt.title(r"$\epsilon = {}$".format(svm_reg2.epsilon), fontsize=18)</code>: Adds the subtitle epsilon with the value used.</li>
#         <li><code>plt.show()</code>: Uses the <a href="https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.show.html">pyplot.show()</a> to display all open figures.</li>
#     </ol>
# </div>

# %% [markdown]
# <hr style="border-top: 5px solid black;">

# %% [markdown]
# <div style="font-size:16px; border:1px solid black; padding:10px">
# <center><h2><br><font color="blue">Final Thoughts</font></h2></center>
#     <ul>
#  <li><mark style="background-color: yellow;">The objective of this post.</mark></li><br>
#         <li>SVM Regression is a powerful method that allows one to choose the level of error in the prediction, both through an acceptable margin of error &epsilon; and through tuning the tolerance of falling outside the acceptable error rate.</li><br>
#         <li>In this post, we demonstrate how Sklearn <code>LinearSVR</code> was used on linear data.</li><br>
#     </ul>
# </div>

# %% [markdown]
# <hr style="border-top: 5px solid black;">
