# %% [markdown]
# <div id="objective2a" style="font-size:14px; border:1px solid black; padding:10px">
# <center><h1><br><font color="blue">Load Data.</font></h1></center>
#     <ul>
#         <li>Data was obtained from <a href="https://sportsdata.io/">SportDataIO</a> and loaded into Pandas dataframe.</li><br>
#         <li>A guide to making an API call to SportDataIO can be obtained in <a href="https://trinidadcisneros.com/folders/python/python_sportsdataio_api.html">A quick and easy guide to make a SportsDataIO API call and load data to Pandas.</a> post.</li><br>
#         <li></li><br>
#         <li></li><br>
#     </ul>
# </div>

# %%
# Dataframe 1 (Offensive Lineman and Cornerback)
group1=['Offensive Lineman', 'Cornerback']
df1 = merged_df.loc[merged_df['Position Title'].isin(group1)].reset_index(drop=True)
df1["target"] = np.where(df1['Position Title'] == 'Cornerback', 1, 0) # add target column


# Save new file
df1.to_csv('static/data/group_df1.csv', index=False)

# %%
x0 = np.linspace(df2.Height_in.min(), df2.Height_in.max(), 200)
pred_1 = np.linspace(250, 250, 200)
pred_2 = -5*x0 + 650

sns.scatterplot(x='Height_in',y='Weight_lbs', data=df1, hue='Position Title')

plt.plot(x0, pred_1, "g--", linewidth=2)
plt.axvline(x=75, c='r', linestyle='--', linewidth=2)
plt.plot(x0, pred_2, "b--", linewidth=2)

plt.xlabel("Height (inches)", fontsize='large')
plt.ylabel("Weight (lbs)", fontsize='large')
plt.title('NFL Player Weight and Height')
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.93))
plt.show()
